# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('../yfinance_projects/stock_L.csv')

# %%
df
# Out:
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2025-01-02  3987.383301  4015.378971  3904.196216
# 1              1  2025-01-03  4033.376221  4033.376221  3953.388591
# 2              2  2025-01-06  4109.364258  4119.362711  4019.378179
# 3              3  2025-01-07  4017.378906  4097.366540  4015.379215
# 4              4  2025-01-08  4115.363770  4123.362533  4001.381391
# ...          ...         ...          ...          ...          ...
# 2785         274  2026-02-02  8234.000000  8328.000000  8066.000000
# 2786         275  2026-02-03  7180.000000  8282.000000  7124.000000
# 2787         276  2026-02-04  7170.000000  7204.000000  6684.000000
# 2788         277  2026-02-05  7586.000000  7871.145996  7298.000000
# 2789         278  2026-02-06  7502.000000  7718.000000  7176.000000
#
#              Open   Volume     stock
# 0     3915.394435   190555  PERSHING
# 1     3959.387663   157161  PERSHING
# 2     4033.376014   141272  PERSHING
# 3     4033.376433   140184  PERSHING
# 4     4001.381391   144012  PERSHING
# ...           ...      ...       ...
# 2785  8102.000000  1392876      LSEG
# 2786  8236.000000  3541135      LSEG
# 2787  7106.000000  4131531      LSEG
# 2788  7340.000000  2907309      LSEG
# 2789  7248.000000  2231651      LSEG
#
# [2790 rows x 8 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Close         float64
# High          float64
# Low           float64
# Open          float64
# Volume          int64
# stock          object
# dtype: object

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print(df.stock.unique())
st=input("Enter stock Name = ")
r=df[df.stock==st]

sb.lineplot(x=r.Date,y=r.Close)
plt.show()
# Out:
# ['PERSHING' 'ADM GRO' 'LEG&GEN' 'SCOTTISH' 'ST.JAMES' 'AVIVA' 'PRUDENTIAL'
#  'STANDARD' 'NATWEST' 'LSEG']
# Enter stock Name =  SCOTTISH
